# %% [markdown]
# ## 코스피 지수 데이터

# %%
#https://github.com/sharebook-kr/pykrx          -> 한국 개발자가 만든 주식 정보 스크래핑 라이브러리
# !pip install pykrx
from pykrx import stock
import numpy as np
# Out:
# Requirement already satisfied: pykrx in c:\anaconda3\lib\site-packages (1.0.40)
# Requirement already satisfied: requests in c:\anaconda3\lib\site-packages (from pykrx) (2.28.2)
# Requirement already satisfied: deprecated in c:\anaconda3\lib\site-packages (from pykrx) (1.2.13)
# Requirement already satisfied: pandas in c:\anaconda3\lib\site-packages (from pykrx) (1.5.2)
# Requirement already satisfied: xlrd in c:\anaconda3\lib\site-packages (from pykrx) (1.2.0)
# Requirement already satisfied: datetime in c:\anaconda3\lib\site-packages (from pykrx) (5.0)
# Requirement already satisfied: numpy in c:\anaconda3\lib\site-packages (from pykrx) (1.24.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\lib\site-packages (from requests->pykrx) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\anaconda3\lib\site-packages (from requests->pykrx) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\lib\site-packages (from requests->pykrx) (2020.6.20)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda3\lib\site-packages (from requests->pykrx) (1.25.11)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\anaconda3\lib\site-packages (from deprecated->pykrx) (1.11.2)
# Requirement already satisfied: pytz>=2020.1 in c:\anaconda3\lib\site-packages (from pandas->pykrx) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\anaconda3\lib\site-packages (from pandas->pykrx) (2.8.1)
# Requirement already satisfied: zope.interface in c:\anaconda3\lib\site-packages (from datetime->pykrx) (5.1.0)
# Requirement already satisfied: six>=1.5 in c:\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->pykrx) (1.15.0)
# Requirement already satisfied: setuptools in c:\anaconda3\lib\site-packages (from zope.interface->datetime->pykrx) (50.3.1.post20201107)

# %%
df = stock.get_index_ohlcv_by_date("20200101","20200831","1001")
df = df[['종가']]
df.head()
# Out:
# 코스피              종가
# 날짜
# 2020-01-02  2175.17
# 2020-01-03  2176.46
# 2020-01-06  2155.07
# 2020-01-07  2175.54
# 2020-01-08  2151.31

# %% [markdown]
# ## 이동 평균선 매매 <br>
#
# 가격이 이동평균선을 돌파하면 매수, 그렇지 않으면 매도

# %%
df['ma'] = df['종가'].rolling( 3 ).mean().shift(1) #rolling 그룹화해주는 함수 -> 그룹화하여 평균을 적용하라
df.head()
# Out:
# 코스피              종가           ma
# 날짜
# 2020-01-02  2175.17          NaN
# 2020-01-03  2176.46          NaN
# 2020-01-06  2155.07          NaN
# 2020-01-07  2175.54  2168.900000
# 2020-01-08  2151.31  2169.023333

# %%
cond  = df['종가'] > df['ma']
df['status'] = np.where(cond,1,0)
df.iloc[-1,-1] = 0
df.head()
# Out:
# 코스피              종가           ma  status
# 날짜
# 2020-01-02  2175.17          NaN       0
# 2020-01-03  2176.46          NaN       0
# 2020-01-06  2155.07          NaN       0
# 2020-01-07  2175.54  2168.900000       1
# 2020-01-08  2151.31  2169.023333       0

# %%
## 0 -> 1 골든크로스 : 매수
## 1 -> 0 데드크로스 : 매도 
df['shift'] = df['status'].shift(1) #df.shift(1) 은 한칸 전에 있던 데이터를 뜻함
df.drop(columns = 'shift')
# Out:
# 코스피              종가           ma  status
# 날짜
# 2020-01-02  2175.17          NaN       0
# 2020-01-03  2176.46          NaN       0
# 2020-01-06  2155.07          NaN       0
# 2020-01-07  2175.54  2168.900000       1
# 2020-01-08  2151.31  2169.023333       0
# ...             ...          ...     ...
# 2020-08-25  2366.73  2302.880000       1
# 2020-08-26  2369.32  2333.716667       1
# 2020-08-27  2344.45  2355.293333       0
# 2020-08-28  2353.80  2360.166667       0
# 2020-08-31  2326.17  2355.856667       0
#
# [166 rows x 3 columns]

# %%
매수조건 = (df['status'] == 1) & (df['status'].shift(1) != 1) #0->1
매도조건 = (df['status'] == 0) & (df['status'].shift(1) == 1) #1->0

# %%
df[매수조건].head()
# Out:
# 코스피              종가           ma  status  shift
# 날짜
# 2020-01-07  2175.54  2168.900000       1    0.0
# 2020-01-09  2186.45  2160.640000       1    0.0
# 2020-01-22  2267.25  2250.966667       1    0.0
# 2020-02-04  2157.90  2128.630000       1    0.0
# 2020-02-11  2223.12  2213.653333       1    0.0

# %%
df[매도조건].head()
# Out:
# 코스피              종가           ma  status  shift
# 날짜
# 2020-01-08  2151.31  2169.023333       0    1.0
# 2020-01-21  2239.69  2253.753333       0    1.0
# 2020-01-23  2246.13  2256.526667       0    1.0
# 2020-02-10  2201.07  2201.840000       0    1.0
# 2020-02-18  2208.88  2239.573333       0    1.0

# %%
수익률 = df.loc[매도조건,'종가'].reset_index(drop=True)/df.loc[매수조건,'종가'].reset_index(drop=True)
수익률 = 수익률 - 0.002
수익률.cumprod().iloc[-1]
# Out:
# 1.2037220606995058

# %% [markdown]
# ### 함수화 하기

# %%
def 단일_이평선_수익률(df,N):
    df = df[['종가']].copy()
    
    #3일 이평선 생성
    df['ma'] = df['종가'].rolling( N ).mean().shift(1)
    
    #종가가 이평선보다 높은 날에 모두 1, 그렇지 않은 날에 0을 추가 (상승 추세판단)
    cond  = df['종가'] > df['ma']
    df['status'] = np.where(cond,1,0)
    df.iloc[-1,-1] = 0
    
    #bool 조건식화 하기
    매수조건 = (df['status'] == 1) & (df['status'].shift(1) != 1)
    매도조건 = (df['status'] == 0) & (df['status'].shift(1) == 1)
    
    #누적 수익률 계산   --> 전체를 넣었다 뺏다하는데, 불려졌으면 그대로 하는 방식(복리)
    수익률 = df.loc[매도조건,'종가'].reset_index(drop=True)/df.loc[매수조건,'종가'].reset_index(drop=True)
    수익률 = 수익률 - 0.002
    
    return 수익률.cumprod().iloc[-1]

# %%
단일_이평선_수익률(df,3)
# Out:
# 1.2037220606995058

# %%
# N일 이평선 중 어떤 N이 가장 효과적인가

index = range(2,61)
result = [단일_이평선_수익률(df,x) for x in index]

# %%
from pandas import Series

s = Series(result,index) #array를 Series 객체로 변환하면
s.sort_values(ascending = False).head() #이렇게 정렬 메서드를 사용할 수 있다.
# Out:
# 7     1.264970
# 34    1.264832
# 33    1.264832
# 31    1.254641
# 32    1.253811
# dtype: float64

# %% [markdown]
# ### 장단기 이평선 교차(골든크로스,데드크로스)<br>
# 단기가 장기를 추월하는 골든크로스 때 매수 <br>
# 장기가 단기를 추월하는 데드크로스 때 매도 <br>

# %%
df1 = df.drop(labels=['ma','status'],axis=1)
df1
# Out:
# 코스피              종가  shift
# 날짜
# 2020-01-02  2175.17    NaN
# 2020-01-03  2176.46    0.0
# 2020-01-06  2155.07    0.0
# 2020-01-07  2175.54    0.0
# 2020-01-08  2151.31    1.0
# ...             ...    ...
# 2020-08-25  2366.73    1.0
# 2020-08-26  2369.32    1.0
# 2020-08-27  2344.45    1.0
# 2020-08-28  2353.80    0.0
# 2020-08-31  2326.17    0.0
#
# [166 rows x 2 columns]

# %%
#sma short moving average
#lma long moving average

df1['sma'] = df1['종가'].rolling( 3 ).mean().shift(1) #오늘을 포함하지 않게 shift 1
df1['lma'] = df1['종가'].rolling( 70 ).mean().shift(1)
df1.tail()
# Out:
# 코스피              종가  shift          sma          lma
# 날짜
# 2020-08-25  2366.73    1.0  2302.880000  2181.380857
# 2020-08-26  2369.32    1.0  2333.716667  2187.518286
# 2020-08-27  2344.45    1.0  2355.293333  2193.071286
# 2020-08-28  2353.80    0.0  2360.166667  2198.140000
# 2020-08-31  2326.17    0.0  2355.856667  2203.218429

# %%
cond  = df1['sma'] > df1['lma']    
df1['status'] = np.where(cond,1,0)
df1.iloc[-1,-1] = 0   #마지막 날에는 무조건 매도하는 걸로
df1
# Out:
# 코스피              종가  shift          sma          lma  status
# 날짜
# 2020-01-02  2175.17    NaN          NaN          NaN       0
# 2020-01-03  2176.46    0.0          NaN          NaN       0
# 2020-01-06  2155.07    0.0          NaN          NaN       0
# 2020-01-07  2175.54    0.0  2168.900000          NaN       0
# 2020-01-08  2151.31    1.0  2169.023333          NaN       0
# ...             ...    ...          ...          ...     ...
# 2020-08-25  2366.73    1.0  2302.880000  2181.380857       1
# 2020-08-26  2369.32    1.0  2333.716667  2187.518286       1
# 2020-08-27  2344.45    1.0  2355.293333  2193.071286       1
# 2020-08-28  2353.80    0.0  2360.166667  2198.140000       1
# 2020-08-31  2326.17    0.0  2355.856667  2203.218429       0
#
# [166 rows x 5 columns]

# %%
    #bool 조건식화 하기
    매수조건 = (df1['status'] == 1) & (df1['status'].shift(1) != 1)
    매도조건 = (df1['status'] == 0) & (df1['status'].shift(1) == 1)

# %%
    수익률 = df1.loc[매도조건,'종가'].reset_index(drop=True)/df.loc[매수조건,'종가'].reset_index(drop=True)
    수익률 = 수익률 - 0.002
    
    수익률.cumprod().iloc[-1]
# Out:
# 1.1978927708848046

# %%
def 장기_단기_이평선_수익률(df,s,l):
    df = df[['종가']].copy()
    
    #sma short moving average
    #lma long moving average

    df['sma'] = df['종가'].rolling( s ).mean().shift(1) #오늘을 포함하지 않게 shift 1
    df['lma'] = df['종가'].rolling( l ).mean().shift(1)
    df.tail()
    
    cond  = df['sma'] > df['lma']    
    df['status'] = np.where(cond,1,0)
    df.iloc[-1,-1] = 0   #마지막 날에는 무조건 매도하는 걸로
    
    #bool 조건식화 하기
    매수조건 = (df['status'] == 1) & (df['status'].shift(1) != 1)
    매도조건 = (df['status'] == 0) & (df['status'].shift(1) == 1)
    
    #누적 수익률 계산   --> 전체를 넣었다 뺏다하는데, 불려졌으면 그대로 하는 방식(복리)
    수익률 = df.loc[매도조건,'종가'].reset_index(drop=True)/df.loc[매수조건,'종가'].reset_index(drop=True)
    수익률 = 수익률 - 0.002
    
    return 수익률.cumprod().iloc[-1]

# %%
df1
장기_단기_이평선_수익률(df1,3,70)
# Out:
# 1.1978927708848046

# %%
result = []
for i in range(2,17):
    for j in range(30,61):
        result.append(장기_단기_이평선_수익률(df1,i,j))
result
# Out:
# [1.2181194699944706,
#  1.2359394826630368,
#  1.235121434328941,
#  1.2270947655960247,
#  1.2720831215493822,
#  1.2720831215493822,
#  1.2720831215493822,
#  1.2720831215493822,
#  1.2506022174716085,
#  1.2130083832585543,
#  1.2130083832585543,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2212784385801925,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1794707358488206,
#  1.2055069390470772,
#  1.2359394826630368,
#  1.2188394149861699,
#  1.2270947655960247,
#  1.2202516452945218,
#  1.2720831215493822,
#  1.2720831215493822,
#  1.2505954724621449,
#  1.2506022174716085,
#  1.2506022174716085,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.1548519375816981,
#  1.1722943171577065,
#  1.171518330510406,
#  1.2020614784966086,
#  1.2202516452945218,
#  1.2720831215493822,
#  1.2505954724621449,
#  1.2506022174716085,
#  1.2506022174716085,
#  1.2506022174716085,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.1548519375816981,
#  1.1947647382813786,
#  1.1939738775990374,
#  1.2020614784966086,
#  1.2202516452945218,
#  1.2628737618342876,
#  1.2505954724621449,
#  1.2506022174716085,
#  1.2506022174716085,
#  1.2130083832585543,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204138099460233,
#  1.1909276826008766,
#  1.208914480366267,
#  1.2081142733284131,
#  1.1957521189280398,
#  1.213846362191735,
#  1.2628737618342876,
#  1.2506022174716085,
#  1.2506022174716085,
#  1.2506022174716085,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.207801484316897,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204138099460233,
#  1.1909276826008766,
#  1.208914480366267,
#  1.1877071669665702,
#  1.1957521189280398,
#  1.213846362191735,
#  1.262880573065947,
#  1.2506022174716085,
#  1.2506022174716085,
#  1.2130083832585543,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204044297890873,
#  1.204138099460233,
#  1.1708108870090634,
#  1.1884938571455526,
#  1.1877071669665702,
#  1.1957585681432625,
#  1.2138529089971415,
#  1.262880573065947,
#  1.2130083832585543,
#  1.2130083832585543,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.207801484316897,
#  1.207801484316897,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204138099460233,
#  1.204138099460233,
#  1.1708108870090634,
#  1.1884938571455526,
#  1.187713572791841,
#  1.1957585681432625,
#  1.1983334237291892,
#  1.20925794318609,
#  1.1951055694590036,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204138099460233,
#  1.1934702901604466,
#  1.1884938571455526,
#  1.1885002672137883,
#  1.172527599811694,
#  1.1449843317189614,
#  1.1623108200313357,
#  1.20925794318609,
#  1.2053021179279333,
#  1.223357677152911,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204044297890873,
#  1.204138099460233,
#  1.1934702901604466,
#  1.1885002672137883,
#  1.1885002672137883,
#  1.172527599811694,
#  1.1449843317189614,
#  1.1623108200313357,
#  1.2195752386152432,
#  1.2053021179279333,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204044297890873,
#  1.204138099460233,
#  1.204138099460233,
#  1.1934702901604466,
#  1.1947302616961053,
#  1.187713572791841,
#  1.137280734276249,
#  1.1449843317189614,
#  1.1722275662295614,
#  1.2195752386152432,
#  1.2053021179279333,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204044297890873,
#  1.204138099460233,
#  1.204138099460233,
#  1.1934702901604466,
#  1.1934702901604466,
#  1.1860166773044085,
#  1.1623108200313357,
#  1.1449843317189614,
#  1.1547532496563302,
#  1.1722275662295614,
#  1.2195752386152432,
#  1.2174944547336406,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204138099460233,
#  1.204138099460233,
#  1.1934702901604466,
#  1.1934702901604466,
#  1.1999065826185802,
#  1.2206634506614096,
#  1.2249176443013448,
#  1.2249176443013448,
#  1.1722275662295614,
#  1.1722275662295614,
#  1.2189069971238842,
#  1.2046413923672632,
#  1.2202420169429935,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.207801484316897,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204044297890873,
#  1.204138099460233,
#  1.1934702901604466,
#  1.1934702901604466,
#  1.1934702901604466,
#  1.1999065826185802,
#  1.201886281933417,
#  1.2130083832585543,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2174944547336406,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.207801484316897,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204044297890873,
#  1.204138099460233,
#  1.204138099460233,
#  1.1934702901604466,
#  1.1934702901604466,
#  1.1999065826185802,
#  1.1999065826185802,
#  1.210517406801487,
#  1.223357677152911,
#  1.223357677152911,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2357326565143825,
#  1.2247858555494027,
#  1.2247858555494027,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2128814715390681,
#  1.2294228087728494,
#  1.2294228087728494,
#  1.207801484316897,
#  1.207801484316897,
#  1.207801484316897,
#  1.2007206593281596,
#  1.2007206593281596,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.1924022263755674,
#  1.2252907136865099,
#  1.2252907136865099,
#  1.204044297890873,
#  1.204138099460233,
#  1.204138099460233,
#  1.1934702901604466,
#  1.1934702901604466,
#  1.1999065826185802,
#  1.1999065826185802,
#  1.208179120473215]

# %%
#멀티 인덱스를 가지는 series를 만들어보자

import pandas as pd
index = pd.MultiIndex.from_product([range(2,17),range(30,61)])
s = Series(result,index)
s.head()
# Out:
# 2  30    1.218119
#    31    1.235939
#    32    1.235121
#    33    1.227095
#    34    1.272083
# dtype: float64

# %%
s.idxmax()
# Out:
# (2, 34)

# %%
s.max()
# Out:
# 1.2720831215493822

# %%
s.groupby(level=0).max()
# Out:
# 2     1.272083
# 3     1.272083
# 4     1.272083
# 5     1.262874
# 6     1.262874
# 7     1.262881
# 8     1.262881
# 9     1.235733
# 10    1.235733
# 11    1.235733
# 12    1.235733
# 13    1.235733
# 14    1.229423
# 15    1.235733
# 16    1.235733
# dtype: float64

# %%
s.groupby(level=1).max()
# Out:
# 30    1.220663
# 31    1.235939
# 32    1.235121
# 33    1.235733
# 34    1.272083
# 35    1.272083
# 36    1.272083
# 37    1.272083
# 38    1.250602
# 39    1.250602
# 40    1.235733
# 41    1.235733
# 42    1.235733
# 43    1.235733
# 44    1.235733
# 45    1.235733
# 46    1.235733
# 47    1.235733
# 48    1.235733
# 49    1.229423
# 50    1.229423
# 51    1.229423
# 52    1.229423
# 53    1.225291
# 54    1.225291
# 55    1.225291
# 56    1.225291
# 57    1.225291
# 58    1.225291
# 59    1.225291
# 60    1.225291
# dtype: float64

# %%
df['종가'].pct_change(3)
# Out:
# 날짜
# 2020-01-02         NaN
# 2020-01-03         NaN
# 2020-01-06         NaN
# 2020-01-07    0.000170
# 2020-01-08   -0.011555
#                 ...
# 2020-08-25    0.040678
# 2020-08-26    0.028087
# 2020-08-27    0.006275
# 2020-08-28   -0.005463
# 2020-08-31   -0.018212
# Name: 종가, Length: 166, dtype: float64

# %% [markdown]
# #### 그래프 그리기 <br>
#
# 최고 수익률을 내는 두 이동평균선이 2, 31이라는 것을 알았으니 <br>
# 두개의 이동평균선을 종가그래프와 함께 그래프에 나타내보자.   <br>

# %%
import matplotlib.pyplot as plt

def make_plot_ma(df, n, m):
    df_new = df['종가'].to_frame()
    df_new['sma_n'] = df_new['종가'].rolling(n).mean().shift(1)
    df_new['sma_m'] = df_new['종가'].rolling(m).mean().shift(1)
    return df_new.plot(figsize = (10,6))

make_plot_ma(df,2,34)
# Out:
# <AxesSubplot:xlabel='날짜'>
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45216 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51676 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0, flags=flags)
